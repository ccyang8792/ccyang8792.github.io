# %% [markdown]
# ##1

# %%
#df

# %%
df2=df[df['total_sales']>0]
df2
# Out:
#             customers  coffee_sold  avg_sale  total_sales        day  \
# date
# 2021-01-01        104           78      4.80       499.20     Friday
# 2021-01-02        118           97      4.78       564.04   Saturday
# 2021-01-03        116           93      4.81       557.96     Sunday
# 2021-01-04        102           71      4.77       486.54     Monday
# 2021-01-05        101           71      4.82       486.82    Tuesday
# ...               ...          ...       ...          ...        ...
# 2021-12-26        123           99      4.79       589.17     Sunday
# 2021-12-27        109           76      4.80       523.20     Monday
# 2021-12-28        111           79      4.80       532.80    Tuesday
# 2021-12-29        114           84      4.81       548.34  Wednesday
# 2021-12-30        110           78      4.80       528.00   Thursday
#
#             total_sales_dow_cummax         MA7        MA30    EWMA_0.2  \
# date
# 2021-01-01                  499.20  499.200000         NaN  499.200000
# 2021-01-02                  564.04  531.620000         NaN  535.222222
# 2021-01-03                  557.96  540.400000         NaN  544.540984
# 2021-01-04                  486.54  526.935000         NaN  524.892954
# 2021-01-05                  486.82  518.912000         NaN  513.567111
# ...                            ...         ...         ...         ...
# 2021-12-26                  751.75  606.368571  562.435000  619.190840
# 2021-12-27                  577.17  606.591429  559.597333  599.992672
# 2021-12-28                  582.01  607.962857  558.162667  586.554138
# 2021-12-29                  612.75  608.811429  559.320667  578.911310
# 2021-12-30                  573.54  609.341429  559.856667  568.729048
#
#              EWMA_0.05  pred_running   pred_roll   pred_ewma
# date
# 2021-01-01  499.200000           NaN         NaN         NaN
# 2021-01-02  532.451282           NaN         NaN         NaN
# 2021-01-03  541.393865           NaN         NaN         NaN
# 2021-01-04  526.607958           NaN         NaN         NaN
# 2021-01-05  517.813837           NaN         NaN         NaN
# ...                ...           ...         ...         ...
# 2021-12-26  569.377458    532.797911  607.558571  626.696050
# 2021-12-27  567.068585    532.954500  606.368571  619.190840
# 2021-12-28  565.355156    532.927479  606.591429  599.992672
# 2021-12-29  564.504398    532.927127  607.962857  586.554138
# 2021-12-30  562.679178    532.969587  608.811429  578.911310
#
# [363 rows x 13 columns]

# %% [markdown]
# ##2

# %%
df2["EWMA_0.15"] = df2["total_sales"].ewm(alpha=0.15).mean()
# Out:
# /tmp/ipython-input-4048800505.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["EWMA_0.15"] = df2["total_sales"].ewm(alpha=0.15).mean()

# %%
df2
# Out:
#             customers  coffee_sold  avg_sale  total_sales        day  \
# date
# 2021-01-01        104           78      4.80       499.20     Friday
# 2021-01-02        118           97      4.78       564.04   Saturday
# 2021-01-03        116           93      4.81       557.96     Sunday
# 2021-01-04        102           71      4.77       486.54     Monday
# 2021-01-05        101           71      4.82       486.82    Tuesday
# ...               ...          ...       ...          ...        ...
# 2021-12-26        123           99      4.79       589.17     Sunday
# 2021-12-27        109           76      4.80       523.20     Monday
# 2021-12-28        111           79      4.80       532.80    Tuesday
# 2021-12-29        114           84      4.81       548.34  Wednesday
# 2021-12-30        110           78      4.80       528.00   Thursday
#
#             total_sales_dow_cummax         MA7        MA30    EWMA_0.2  \
# date
# 2021-01-01                  499.20  499.200000         NaN  499.200000
# 2021-01-02                  564.04  531.620000         NaN  535.222222
# 2021-01-03                  557.96  540.400000         NaN  544.540984
# 2021-01-04                  486.54  526.935000         NaN  524.892954
# 2021-01-05                  486.82  518.912000         NaN  513.567111
# ...                            ...         ...         ...         ...
# 2021-12-26                  751.75  606.368571  562.435000  619.190840
# 2021-12-27                  577.17  606.591429  559.597333  599.992672
# 2021-12-28                  582.01  607.962857  558.162667  586.554138
# 2021-12-29                  612.75  608.811429  559.320667  578.911310
# 2021-12-30                  573.54  609.341429  559.856667  568.729048
#
#              EWMA_0.05  pred_running   pred_roll   pred_ewma   EWMA_0.15
# date
# 2021-01-01  499.200000           NaN         NaN         NaN  499.200000
# 2021-01-02  532.451282           NaN         NaN         NaN  534.248649
# 2021-01-03  541.393865           NaN         NaN         NaN  543.465889
# 2021-01-04  526.607958           NaN         NaN         NaN  525.601883
# 2021-01-05  517.813837           NaN         NaN         NaN  515.144687
# ...                ...           ...         ...         ...         ...
# 2021-12-26  569.377458    532.797911  607.558571  626.696050  605.089883
# 2021-12-27  567.068585    532.954500  606.368571  619.190840  592.806401
# 2021-12-28  565.355156    532.927479  606.591429  599.992672  583.805441
# 2021-12-29  564.504398    532.927127  607.962857  586.554138  578.485624
# 2021-12-30  562.679178    532.969587  608.811429  578.911310  570.912781
#
# [363 rows x 14 columns]

# %%
plt.figure(figsize=(14,5))
plt.plot(df2["total_sales"], alpha=0.4, label="Raw")
plt.plot(df2["EWMA_0.15"], label="EWMA α=0.15")
plt.legend()

# %%
august_13=df2[df2.index=='2021-08-13']

# %%
august_13
# Out:
#             customers  coffee_sold  avg_sale  total_sales     day  \
# date
# 2021-08-13        108           80      4.76       514.08  Friday
#
#             total_sales_dow_cummax         MA7        MA30    EWMA_0.2  \
# date
# 2021-08-13                  590.24  556.532857  549.303333  543.173993
#
#              EWMA_0.05  pred_running   pred_roll   pred_ewma   EWMA_0.15
# date
# 2021-08-13  544.569722    526.214375  567.412857  550.447491  548.983305

# %%
error = abs(august_13['total_sales']-august_13['EWMA_0.15'])

# %%
error
# Out:
# date
# 2021-08-13    34.903305
# dtype: float64

# %% [markdown]
# ##3

# %%
df2=df2.rename(columns={'MA7':'pred_roll_mean'})

# %%
df2['pred_roll_med'] = df2["total_sales"].rolling(window = 7, min_periods = 1).median()
#df2

# %%
#df2

# %%
sept_17=df2[df2.index=='2021-09-17']

# %%
sept_17
# Out:
#             customers  coffee_sold  avg_sale  total_sales     day  \
# date
# 2021-09-17        110           84      4.75        522.5  Friday
#
#             total_sales_dow_cummax  pred_roll_mean        MA30    EWMA_0.2  \
# date
# 2021-09-17                  590.24      534.515714  531.532667  526.138899
#
#              EWMA_0.05  pred_running   pred_roll   pred_ewma   EWMA_0.15  \
# date
# 2021-09-17  533.332118    527.095444  534.877143  527.048623  527.831182
#
#             pred_roll_med
# date
# 2021-09-17          522.5

# %%
plt.figure(figsize=(14,5))
plt.plot(df2["total_sales"], label="Raw Daily Sales", alpha=0.4)
plt.plot(df2['pred_roll_mean'], label="7-Day Mean Average", linewidth=2)
plt.plot(df2['pred_roll_med'], label="7-Day Median Average", linewidth=2)
plt.title("Raw Data vs Moving Average vs Moving Median")
plt.xlabel("Date")
plt.ylabel("Sales ($)")
plt.legend()
plt.show()

# %%
mean_diff= abs(sept_17['total_sales']-sept_17['pred_roll_mean'])
mean_diff
# Out:
# date
# 2021-09-17    12.015714
# dtype: float64

# %%
median_diff= abs(sept_17['total_sales']-sept_17['pred_roll_med'])
median_diff
# Out:
# date
# 2021-09-17    0.0
# dtype: float64

# %% [markdown]
# ##4

# %%
#df2

# %%
cust_ma= df2['customers'].rolling(window = 14, min_periods = 1).mean()
#cust_ma

# %%
cust_ewa= df2['customers'].ewm(alpha=0.10).mean()
cust_ewa2= df2['customers'].ewm(alpha=0.25).mean()
#cust_ewa

# %%
plt.figure(figsize=(14,5))
plt.plot(df2['customers'], label='Daily Customers Count', alpha=0.4)
plt.plot(cust_ma, label='14-Day Mean Average', linewidth=2)
plt.plot(cust_ewa, label='EWMA α=0.10')
plt.title('Daily Customer Count vs Forecasted Trends')
plt.xlabel("Date")
plt.ylabel('Count')
plt.legend()
plt.show()

# %% [markdown]
# ##5

# %%
import numpy as np
cust_ewa= df2['customers'].ewm(alpha=0.10).mean()
cust_ewa2= df2['customers'].ewm(alpha=0.25).mean()

errors = df2['customers'] - cust_ewa
errors2 = df2['customers'] - cust_ewa2
MAPE = (errors.abs() / df['customers']).replace([np.inf,np.nan],0).mean() * 100
MAPE2 = (errors2.abs() / df['customers']).replace([np.inf,np.nan],0).mean() * 100
print(MAPE)
print(MAPE2)
# Out:
# 5.478809262031625
# 4.712170145759009

# %% [markdown]
# In refence to the data I used in question #4, having a higher α of .25 compared to .10 drop the MAPE by 0.77 percentage.  Therefore, it made the MAPE better.

# %% [markdown]
# ##6

# %%
dmonth = df2["total_sales"].resample("ME").sum()

# %%
dmonth
# Out:
# date
# 2021-01-31    15960.57
# 2021-02-28    14713.72
# 2021-03-31    16179.02
# 2021-04-30    15777.59
# 2021-05-31    16472.81
# 2021-06-30    15964.00
# 2021-07-31    15902.57
# 2021-08-31    17046.04
# 2021-09-30    15961.92
# 2021-10-31    16778.50
# 2021-11-30    16443.52
# 2021-12-31    16795.70
# Freq: ME, Name: total_sales, dtype: float64

# %%
dmonth.sort_values()
# Out:
# date
# 2021-02-28    14713.72
# 2021-04-30    15777.59
# 2021-07-31    15902.57
# 2021-01-31    15960.57
# 2021-09-30    15961.92
# 2021-06-30    15964.00
# 2021-03-31    16179.02
# 2021-11-30    16443.52
# 2021-05-31    16472.81
# 2021-10-31    16778.50
# 2021-12-31    16795.70
# 2021-08-31    17046.04
# Name: total_sales, dtype: float64

# %% [markdown]
# Feburary had the least amount of sales.

# %%
dmonth.plot(kind='line',ylabel='Sales', xlabel='', grid=True, marker='o')
# Out:
# <Axes: ylabel='Sales'>

# %% [markdown]
# ##7

# %%
dmonth
# Out:
# date
# 2021-01-31    15960.57
# 2021-02-28    14713.72
# 2021-03-31    16179.02
# 2021-04-30    15777.59
# 2021-05-31    16472.81
# 2021-06-30    15964.00
# 2021-07-31    15902.57
# 2021-08-31    17046.04
# 2021-09-30    15961.92
# 2021-10-31    16778.50
# 2021-11-30    16443.52
# 2021-12-31    16795.70
# Freq: ME, Name: total_sales, dtype: float64

# %%
cum_max=dmonth.cummax()
cum_max
# Out:
# date
# 2021-01-31    15960.57
# 2021-02-28    15960.57
# 2021-03-31    16179.02
# 2021-04-30    16179.02
# 2021-05-31    16472.81
# 2021-06-30    16472.81
# 2021-07-31    16472.81
# 2021-08-31    17046.04
# 2021-09-30    17046.04
# 2021-10-31    17046.04
# 2021-11-30    17046.04
# 2021-12-31    17046.04
# Freq: ME, Name: total_sales, dtype: float64

# %%
cum_min=dmonth.cummin()
cum_min
# Out:
# date
# 2021-01-31    15960.57
# 2021-02-28    14713.72
# 2021-03-31    14713.72
# 2021-04-30    14713.72
# 2021-05-31    14713.72
# 2021-06-30    14713.72
# 2021-07-31    14713.72
# 2021-08-31    14713.72
# 2021-09-30    14713.72
# 2021-10-31    14713.72
# 2021-11-30    14713.72
# 2021-12-31    14713.72
# Freq: ME, Name: total_sales, dtype: float64

# %%
dmonth=dmonth.to_frame()

# %%
dmonth['cum_range']=cum_max-cum_min

# %%
dmonth
# Out:
#             total_sales  cum_range
# date
# 2021-01-31     15960.57       0.00
# 2021-02-28     14713.72    1246.85
# 2021-03-31     16179.02    1465.30
# 2021-04-30     15777.59    1465.30
# 2021-05-31     16472.81    1759.09
# 2021-06-30     15964.00    1759.09
# 2021-07-31     15902.57    1759.09
# 2021-08-31     17046.04    2332.32
# 2021-09-30     15961.92    2332.32
# 2021-10-31     16778.50    2332.32
# 2021-11-30     16443.52    2332.32
# 2021-12-31     16795.70    2332.32

# %%
dmonth.plot(y='cum_range')
# Out:
# <Axes: xlabel='date'>

# %% [markdown]
# ##8

# %%
path = r'https://raw.githubusercontent.com/ncrowder/python/refs/heads/main/timeseries_full.csv'
df_orig = pd.read_csv(path, parse_dates= ['date'])
path2 = r'https://raw.githubusercontent.com/ncrowder/python/refs/heads/main/dec2021_jan2022_adjusted.csv'
df_new = pd.read_csv(path2, parse_dates=['date'])

# %%
df_orig
# Out:
#           date  customers  coffee_sold  avg_sale  total_sales
# 0   2021-01-01        104           78      4.80       499.20
# 1   2021-01-02        118           97      4.78       564.04
# 2   2021-01-03        116           93      4.81       557.96
# 3   2021-01-04        102           71      4.77       486.54
# 4   2021-01-05        101           71      4.82       486.82
# ..         ...        ...          ...       ...          ...
# 360 2021-12-27        109           76      4.80       523.20
# 361 2021-12-28        111           79      4.80       532.80
# 362 2021-12-29        114           84      4.81       548.34
# 363 2021-12-30        110           78      4.80       528.00
# 364 2021-12-31          0            0      4.81         0.00
#
# [365 rows x 5 columns]

# %%
df_new
# Out:
#          date  customers  coffee_sold  avg_sale  total_sales
# 0  2021-12-01        115           84      4.77       548.55
# 1  2021-12-02        112           79      4.75       532.00
# 2  2021-12-03        110           84      4.75       522.50
# 3  2021-12-04        126          102      4.80       604.80
# 4  2021-12-05        124           97      4.77       591.48
# ..        ...        ...          ...       ...          ...
# 57 2022-01-27        113           80      4.81       543.53
# 58 2022-01-28        113           85      4.84       546.92
# 59 2022-01-29        134          110      4.86       651.24
# 60 2022-01-30        125          100      4.84       605.00
# 61 2022-01-31        110           75      4.83       531.30
#
# [62 rows x 5 columns]

# %%
df_combine=pd.concat([df_orig, df_new])

# %%
df_combine=df_combine.drop_duplicates(subset='date')

# %%
df_combine
# Out:
#          date  customers  coffee_sold  avg_sale  total_sales
# 0  2021-01-01        104           78      4.80       499.20
# 1  2021-01-02        118           97      4.78       564.04
# 2  2021-01-03        116           93      4.81       557.96
# 3  2021-01-04        102           71      4.77       486.54
# 4  2021-01-05        101           71      4.82       486.82
# ..        ...        ...          ...       ...          ...
# 57 2022-01-27        113           80      4.81       543.53
# 58 2022-01-28        113           85      4.84       546.92
# 59 2022-01-29        134          110      4.86       651.24
# 60 2022-01-30        125          100      4.84       605.00
# 61 2022-01-31        110           75      4.83       531.30
#
# [396 rows x 5 columns]

# %%
df_combine['date']
# Out:
# 0    2021-01-01
# 1    2021-01-02
# 2    2021-01-03
# 3    2021-01-04
# 4    2021-01-05
#         ...
# 57   2022-01-27
# 58   2022-01-28
# 59   2022-01-29
# 60   2022-01-30
# 61   2022-01-31
# Name: date, Length: 396, dtype: datetime64[ns]

# %%
df_combine.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_combine
# Out:
#          date  customers  coffee_sold  avg_sale  total_sales
# 0  2021-01-01        104           78      4.80       499.20
# 1  2021-01-02        118           97      4.78       564.04
# 2  2021-01-03        116           93      4.81       557.96
# 3  2021-01-04        102           71      4.77       486.54
# 4  2021-01-05        101           71      4.82       486.82
# ..        ...        ...          ...       ...          ...
# 57 2022-01-27        113           80      4.81       543.53
# 58 2022-01-28        113           85      4.84       546.92
# 59 2022-01-29        134          110      4.86       651.24
# 60 2022-01-30        125          100      4.84       605.00
# 61 2022-01-31        110           75      4.83       531.30
#
# [396 rows x 5 columns]

# %%
df_combine["EWMA_0.15"] = df_combine["total_sales"].ewm(alpha=0.15).mean()

# %%
df_combine=df_combine.set_index('date')

# %%
df_combine
# Out:
#             customers  coffee_sold  avg_sale  total_sales   EWMA_0.15
# date
# 2021-01-01        104           78      4.80       499.20  499.200000
# 2021-01-02        118           97      4.78       564.04  534.248649
# 2021-01-03        116           93      4.81       557.96  543.465889
# 2021-01-04        102           71      4.77       486.54  525.601883
# 2021-01-05        101           71      4.82       486.82  515.144687
# ...               ...          ...       ...          ...         ...
# 2022-01-27        113           80      4.81       543.53  556.334642
# 2022-01-28        113           85      4.84       546.92  554.922446
# 2022-01-29        134          110      4.86       651.24  569.370079
# 2022-01-30        125          100      4.84       605.00  574.714567
# 2022-01-31        110           75      4.83       531.30  568.202382
#
# [396 rows x 5 columns]

# %%
plt.figure(figsize=(14,5))
plt.plot(df_combine["total_sales"], alpha=0.4, label="Raw")
plt.plot(df_combine["EWMA_0.15"], label="EWMA α=0.15")
plt.legend()

# %%
august_13_combine=df_combine[df_combine.index=='2021-08-13']

# %%
august_13_combine
# Out:
#             customers  coffee_sold  avg_sale  total_sales   EWMA_0.15
# date
# 2021-08-13        108           80      4.76       514.08  548.862548

# %%
error= august_13_combine['total_sales']- august_13_combine['EWMA_0.15']

# %%
error.abs()
# Out:
# date
# 2021-08-13    34.782548
# dtype: float64
